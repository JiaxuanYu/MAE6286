# %%
import numpy
import sympy
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 16

# %%
sympy.init_printing()

# %%
x = sympy.symbols('x')

# %%
x
# Out:
# x

# %%
5 * x
# Out:
# 5⋅x

# %%
x, nu, t = sympy.symbols('x nu t')
phi = (sympy.exp(-(x - 4 * t)**2 / (4 * nu * (t + 1))) +
       sympy.exp(-(x - 4 * t - 2 * numpy.pi)**2 / (4 * nu * (t + 1))))
phi
# Out:
#                                2                2
#  -(-4⋅t + x - 6.28318530717959)      -(-4⋅t + x)
#  ────────────────────────────────    ─────────────
#            4⋅ν⋅(t + 1)                4⋅ν⋅(t + 1)
# ℯ                                 + ℯ

# %%
phiprime = phi.diff(x)
phiprime
# Out:
#                            2
#                 -(-4⋅t + x)                                      -(-4⋅t + x -
#                 ─────────────                                    ─────────────
#                  4⋅ν⋅(t + 1)                                               4⋅ν
#   (-8⋅t + 2⋅x)⋅ℯ                (-8⋅t + 2⋅x - 12.5663706143592)⋅ℯ
# - ─────────────────────────── - ──────────────────────────────────────────────
#           4⋅ν⋅(t + 1)                                      4⋅ν⋅(t + 1)
#
#                  2
# 6.28318530717959)
# ───────────────────
# ⋅(t + 1)
#
# ───────────────────

# %%
print(phiprime)
# Out:
# -(-8*t + 2*x)*exp(-(-4*t + x)**2/(4*nu*(t + 1)))/(4*nu*(t + 1)) - (-8*t + 2*x - 12.5663706143592)*exp(-(-4*t + x - 6.28318530717959)**2/(4*nu*(t + 1)))/(4*nu*(t + 1))

# %%
from sympy.utilities.lambdify import lambdify
u = -2 * nu * (phiprime / phi) + 4
print(u)
# Out:
# -2*nu*(-(-8*t + 2*x)*exp(-(-4*t + x)**2/(4*nu*(t + 1)))/(4*nu*(t + 1)) - (-8*t + 2*x - 12.5663706143592)*exp(-(-4*t + x - 6.28318530717959)**2/(4*nu*(t + 1)))/(4*nu*(t + 1)))/(exp(-(-4*t + x - 6.28318530717959)**2/(4*nu*(t + 1))) + exp(-(-4*t + x)**2/(4*nu*(t + 1)))) + 4

# %%
u_lamb = lambdify((t, x, nu), u)
print('The value of u at t=1, x=4, nu=3 is {}'.format(u_lamb(1, 4, 3)))
# Out:
# The value of u at t=1, x=4, nu=3 is 3.4917066420644494

# %%
nx = 101
L = 2.0 * numpy.pi
dx = L / (nx - 1)
nu = 0.07
nt = 100
sigma = 0.1
dt = sigma * dx**2 / nu

x = numpy.linspace(0.0, L, num=nx)

# %%
t = 0.0
u0 = numpy.array([u_lamb(t, xi, nu) for xi in x])
u0
# Out:
# array([4.        , 4.06283185, 4.12566371, 4.18849556, 4.25132741,
#        4.31415927, 4.37699112, 4.43982297, 4.50265482, 4.56548668,
#        4.62831853, 4.69115038, 4.75398224, 4.81681409, 4.87964594,
#        4.9424778 , 5.00530965, 5.0681415 , 5.13097336, 5.19380521,
#        5.25663706, 5.31946891, 5.38230077, 5.44513262, 5.50796447,
#        5.57079633, 5.63362818, 5.69646003, 5.75929189, 5.82212374,
#        5.88495559, 5.94778745, 6.0106193 , 6.07345115, 6.136283  ,
#        6.19911486, 6.26194671, 6.32477856, 6.38761042, 6.45044227,
#        6.51327412, 6.57610598, 6.63893783, 6.70176967, 6.76460125,
#        6.82742866, 6.89018589, 6.95176632, 6.99367964, 6.72527549,
#        4.        , 1.27472451, 1.00632036, 1.04823368, 1.10981411,
#        1.17257134, 1.23539875, 1.29823033, 1.36106217, 1.42389402,
#        1.48672588, 1.54955773, 1.61238958, 1.67522144, 1.73805329,
#        1.80088514, 1.863717  , 1.92654885, 1.9893807 , 2.05221255,
#        2.11504441, 2.17787626, 2.24070811, 2.30353997, 2.36637182,
#        2.42920367, 2.49203553, 2.55486738, 2.61769923, 2.68053109,
#        2.74336294, 2.80619479, 2.86902664, 2.9318585 , 2.99469035,
#        3.0575222 , 3.12035406, 3.18318591, 3.24601776, 3.30884962,
#        3.37168147, 3.43451332, 3.49734518, 3.56017703, 3.62300888,
#        3.68584073, 3.74867259, 3.81150444, 3.87433629, 3.93716815,
#        4.        ])

# %%
plt.figure(figsize=(6.0, 4.0))
plt.title('Initial conditions')
plt.xlabel('x')
plt.ylabel('u')
plt.grid()
plt.plot(x, u0, color='C0', linestyle='-', linewidth=2)
plt.xlim(0.0, L)
plt.ylim(0.0, 10.0);

# %%
u = u0.copy()
for n in range(nt):
    un = u.copy()
    u[1:-1] = (un[1:-1] -
               un[1:-1] * dt / dx * (un[1:-1] - un[:-2]) +
               nu * dt / dx**2 * (un[2:] - 2 * un[1:-1] + un[:-2]))
    u[0] = (un[0] -
            un[0] * dt / dx * (un[0] - un[-1]) +
            nu * dt / dx**2 * (un[1] - 2 * un[0] + un[-1]))
    u[-1] = (un[-1] -
            un[-1] * dt / dx * (un[-1] - un[-2]) +
            nu * dt / dx**2 * (un[0] - 2 * un[-1] + un[-2]))

# %%
u_analytical = numpy.array([u_lamb(nt * dt, xi, nu) for xi in x])

# %%
plt.figure(figsize=(6.0, 4.0))
plt.xlabel('x')
plt.ylabel('u')
plt.grid()
plt.plot(x, u, label='Numerical', color='b', linestyle='-', linewidth=2)
plt.plot(x, u_analytical, label='Analytical', color='C1', linestyle='--', linewidth=2)
plt.legend()
plt.xlim(0.0, L)
plt.ylim(0.0, 10.0);

# %%
from matplotlib import animation
from IPython.display import HTML

# %%
def burgers(u0, dx, dt, nu, nt=20):
    u_hist = [u0.copy()]
    u = u0.copy()
    for n in range(nt):
        un = u.copy()
 
        u[1:-1] = (un[1:-1] - un[1:-1] * dt / dx * (un[1:-1] - un[:-2]) + nu * dt / dx**2 * (un[2:] - 2 * un[1:-1] + 
                                                                                             un[:-2]))
  
        u[0] = (un[0] - un[0] * dt / dx * (un[0] - un[-1]) + nu * dt / dx**2 * (un[1] - 2 * un[0] + un[-1]))
        u[-1] = (un[-1] - un[-1] * dt / dx * (un[-1] - un[-2]) + nu * dt / dx**2 * (un[0] - 2 * un[-1] + un[-2]))
        u_hist.append(u.copy())
    return u_hist

# %%
u_hist = burgers(u0, dx, dt, nu, nt=nt)

# %%
u_analytical = [numpy.array([u_lamb(n * dt, xi, nu) for xi in x])
                for n in range(nt)]

# %%
fig = plt.figure(figsize=(6.0, 4.0))
plt.xlabel('x')
plt.ylabel('u')
plt.grid()
u0_analytical = numpy.array([u_lamb(0.0, xi, nu) for xi in x])
line1 = plt.plot(x, u0, label='Numerical', color='B', linestyle='-', linewidth=2)[0]
line2 = plt.plot(x, u0_analytical, label='Analytical', color='C1', linestyle='--', linewidth=2)[0]
plt.legend()
plt.xlim(0.0, L)
plt.ylim(0.0, 10.0)
fig.tight_layout()

# %%
def update_plot(n, u_hist, u_analytical):
    fig.suptitle('Time step {:0>2}'.format(n))
    line1.set_ydata(u_hist[n])
    line2.set_ydata(u_analytical[n])

# %%
anim = animation.FuncAnimation(fig, update_plot,
                               frames=nt, fargs=(u_hist, u_analytical),
                               interval=100)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# %%timeit

u = numpy.array([u_lamb(t, x0, nu) for x0 in x])

for n in range(nt):
    un = u.copy()
    
    for i in range(nx - 1):
        u[i] = (un[i] - un[i] * dt / dx *(un[i] - un[i - 1]) + nu * dt / dx**2 * (un[i + 1] - 2 * un[i] + un[i - 1]))
   
        u[-1] = (un[-1] - un[-1] * dt / dx * (un[-1] - un[-2]) + nu * dt / dx**2 * (un[0]- 2 * un[-1] + un[-2]))
# Out:
# 41.2 ms ± 145 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
